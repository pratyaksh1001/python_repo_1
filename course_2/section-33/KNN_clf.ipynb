# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt

# %%
x,y=make_classification(n_samples=1000,n_features=5,n_classes=3,n_informative=3)

# %%
x
# Out:
# array([[-0.16778286, -1.24220193, -1.65978125,  2.23714513, -1.46463899],
#        [ 0.46557918,  1.44512256, -0.86065991,  1.88161075,  1.01509501],
#        [ 0.57955565,  1.26170057, -0.00588403,  0.74588382,  0.95636887],
#        ...,
#        [-0.47774705,  0.87839642, -0.94497004,  0.83867027,  0.88496883],
#        [-2.53477798,  4.04679386, -2.88581607,  1.27127544,  4.52815251],
#        [ 3.47918459, -0.99553322,  1.2156334 ,  2.43552   , -2.33726381]])

# %%
plt.scatter(x[:,1],x[:,0],c=y)

# %%
knn=KNeighborsClassifier(n_neighbors=5,algorithm="ball_tree")

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='ball_tree')

# %%
knn.score(x_test,y_test)
# Out:
# 0.88
