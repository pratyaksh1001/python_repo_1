# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("train.csv")

# %%
df["Age"]=df["Age"].fillna(df["Age"].mean(),)

# %%
#df["Age"].fillna(df["Age"].mean(),inplace=True)
df=df.replace("LINE","0")

# %%
df[df["Cabin"].isna()].shape
# Out:
# (687, 12)

# %%
df.shape
# Out:
# (891, 12)

# %%
df[df["Ticket"]=="0"].shape
# Out:
# (4, 12)

# %%
l=[]
for i in df["Ticket"]:
    i=str(i)
    t=i.split(" ")
    l.append(int(t[-1]))

# %%
l
# Out:
# [21171,
#  17599,
#  3101282,
#  113803,
#  373450,
#  330877,
#  17463,
#  349909,
#  347742,
#  237736,
#  9549,
#  113783,
#  2151,
#  347082,
#  350406,
#  248706,
#  382652,
#  244373,
#  345763,
#  2649,
#  239865,
#  248698,
#  330923,
#  113788,
#  349909,
#  347077,
#  2631,
#  19950,
#  330959,
#  349216,
#  17601,
#  17569,
#  335677,
#  24579,
#  17604,
#  113789,
#  2677,
#  2152,
#  345764,
#  2651,
#  7546,
#  11668,
#  349253,
#  2123,
#  330958,
#  23567,
#  370371,
#  14311,
#  2662,
#  349237,
#  3101295,
#  39886,
#  17572,
#  2926,
#  113509,
#  19947,
#  31026,
#  2697,
#  34651,
#  2144,
#  2669,
#  113572,
#  36973,
#  347088,
#  17605,
#  2661,
#  29395,
#  3464,
#  3101281,
#  315151,
#  33111,
#  2144,
#  14879,
#  2680,
#  1601,
#  348123,
#  349208,
#  374746,
#  248738,
#  364516,
#  345767,
#  345779,
#  330932,
#  113059,
#  14885,
#  3101278,
#  6608,
#  392086,
#  19950,
#  343275,
#  343276,
#  347466,
#  5734,
#  2315,
#  364500,
#  374910,
# ...

# %%
df["Ticket"]=l

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.drop("Cabin",inplace=True,axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df[df["Embarked"].isna()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Embarked
# 61   female  38.0      0      0  113572  80.0      NaN
# 829  female  62.0      0      0  113572  80.0      NaN

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Embarked
# ...

# %%
df2=df.dropna(axis=0)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df2=df2.drop(["Name","PassengerId"],axis=1)

# %%
df2.replace({"male":0,"female":1},inplace=True)
df2
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch   Ticket     Fare Embarked
# 0           0       3    0  22.000000      1      0    21171   7.2500        S
# 1           1       1    1  38.000000      1      0    17599  71.2833        C
# 2           1       3    1  26.000000      0      0  3101282   7.9250        S
# 3           1       1    1  35.000000      1      0   113803  53.1000        S
# 4           0       3    0  35.000000      0      0   373450   8.0500        S
# ..        ...     ...  ...        ...    ...    ...      ...      ...      ...
# 886         0       2    0  27.000000      0      0   211536  13.0000        S
# 887         1       1    1  19.000000      0      0   112053  30.0000        S
# 888         0       3    1  29.699118      1      2     6607  23.4500        S
# 889         1       1    0  26.000000      0      0   111369  30.0000        C
# 890         0       3    0  32.000000      0      0   370376   7.7500        Q
#
# [889 rows x 9 columns]

# %%
df3=pd.get_dummies(df2,prefix="Embarked",drop_first=True)

# %%
df3
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch   Ticket     Fare  \
# 0           0       3    0  22.000000      1      0    21171   7.2500
# 1           1       1    1  38.000000      1      0    17599  71.2833
# 2           1       3    1  26.000000      0      0  3101282   7.9250
# 3           1       1    1  35.000000      1      0   113803  53.1000
# 4           0       3    0  35.000000      0      0   373450   8.0500
# ..        ...     ...  ...        ...    ...    ...      ...      ...
# 886         0       2    0  27.000000      0      0   211536  13.0000
# 887         1       1    1  19.000000      0      0   112053  30.0000
# 888         0       3    1  29.699118      1      2     6607  23.4500
# 889         1       1    0  26.000000      0      0   111369  30.0000
# 890         0       3    0  32.000000      0      0   370376   7.7500
#
#      Embarked_Q  Embarked_S
# 0         False        True
# 1         False       False
# 2         False        True
# ...

# %%
df3.replace({True:1,False:0},inplace=True)
# Out:
# C:\Users\praty\AppData\Local\Temp\ipykernel_20488\1863060307.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df3.replace({True:1,False:0},inplace=True)

# %%
df3
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch   Ticket     Fare  \
# 0           0       3    0  22.000000      1      0    21171   7.2500
# 1           1       1    1  38.000000      1      0    17599  71.2833
# 2           1       3    1  26.000000      0      0  3101282   7.9250
# 3           1       1    1  35.000000      1      0   113803  53.1000
# 4           0       3    0  35.000000      0      0   373450   8.0500
# ..        ...     ...  ...        ...    ...    ...      ...      ...
# 886         0       2    0  27.000000      0      0   211536  13.0000
# 887         1       1    1  19.000000      0      0   112053  30.0000
# 888         0       3    1  29.699118      1      2     6607  23.4500
# 889         1       1    0  26.000000      0      0   111369  30.0000
# 890         0       3    0  32.000000      0      0   370376   7.7500
#
#      Embarked_Q  Embarked_S
# 0             0           1
# 1             0           0
# 2             0           1
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
import sklearn

# %%
model=sklearn.ensemble.RandomForestClassifier(n_estimators=100,max_depth=10,random_state=0)

# %%
x=df3.drop("Survived",axis=1).to_numpy()

# %%
y=df3["Survived"].to_numpy()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10, random_state=0)

# %%
model.score(x_test,y_test)
# Out:
# 0.8314606741573034

# %%
x_test=x_test.to_numpy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 x_test=x_test.to_numpy()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_numpy'

# %%
x_test[0]
# Out:
# array([3.00000e+00, 0.00000e+00, 3.30000e+01, 0.00000e+00, 0.00000e+00,
#        3.47062e+05, 7.77500e+00, 0.00000e+00, 1.00000e+00])

# %%
model.predict((x_test[130],))
# Out:
# array([1], dtype=int64)

# %%
y_test[130]
# Out:
# 1

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex        Age  \
# 0                                Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.000000
# 2                                 Heikkinen, Miss. Laina  female  26.000000
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                               Allen, Mr. William Henry    male  35.000000
# ..                                                   ...     ...        ...
# ...

# %%
df.plot(x=[""])

# %%
x
# Out:
# array(['male', 'female'], dtype=object)

# %%
df[df["Survived"]==1]["Sex"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Sex'>

# %%
df[df["Survived"]==0]["Sex"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Sex'>

# %%
p1=df[df["Survived"]==0].groupby("Sex")["Survived"].value_counts().plot(kind="bar",color="red")

# %%
p2=df[df["Survived"]==1].groupby("Sex")["Survived"].value_counts().plot(kind="bar",color="green",stacked=True)

# %%
df["Sex"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Sex'>

# %%
(df["Sex"].value_counts()/len(df)*100).plot(kind="bar")
# Out:
# <Axes: xlabel='Sex'>
