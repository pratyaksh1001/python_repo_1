# %%
import tensorflow as tf

# %%
import tensorflow.keras as keras

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("zomato (1).csv")

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-07-23  116.000000  138.899994  115.000000  126.000000  126.000000
# 1    2021-07-26  126.349998  143.750000  125.300003  140.649994  140.649994
# 2    2021-07-27  141.699997  147.800003  127.750000  132.899994  132.899994
# 3    2021-07-28  131.000000  135.000000  123.550003  131.199997  131.199997
# 4    2021-07-29  134.949997  144.000000  132.199997  141.550003  141.550003
# ..          ...         ...         ...         ...         ...         ...
# 626  2024-02-01  141.000000  143.500000  138.550003  140.550003  140.550003
# 627  2024-02-02  141.800003  145.000000  141.449997  143.800003  143.800003
# 628  2024-02-05  145.000000  145.399994  138.250000  140.250000  140.250000
# 629  2024-02-06  140.399994  141.800003  138.050003  139.949997  139.949997
# 630  2024-02-07  141.000000  142.899994  139.649994  140.399994  140.399994
#
#         Volume
# 0    694895290
# 1    249723854
# ...

# %%
test=df.iloc[600:]

# %%
test
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 600  2023-12-26  128.500000  128.699997  124.300003  125.000000  125.000000
# 601  2023-12-27  125.699997  127.599998  125.550003  127.050003  127.050003
# 602  2023-12-28  124.900002  125.500000  120.599998  123.199997  123.199997
# 603  2023-12-29  124.000000  125.550003  123.250000  123.699997  123.699997
# 604  2024-01-01  124.449997  125.599998  122.849998  124.500000  124.500000
# 605  2024-01-02  127.000000  129.449997  125.500000  128.699997  128.699997
# 606  2024-01-03  128.800003  130.250000  127.099998  127.550003  127.550003
# 607  2024-01-04  128.399994  130.899994  126.449997  129.750000  129.750000
# 608  2024-01-05  130.899994  134.350006  128.949997  133.300003  133.300003
# 609  2024-01-08  133.649994  133.649994  130.000000  132.850006  132.850006
# 610  2024-01-09  133.199997  135.000000  132.600006  134.300003  134.300003
# ...

# %%
plt.bar(df["year"],df["Open"],color="green")
plt.savefig("zomato(1).png")

# %%
plt.hist2d(df["Open"],[i for i in range(len(df["Open"]))],color="red")
# Out:
# (array([[ 0.,  0.,  0.,  3.,  6.,  7., 26.,  0.,  0.,  0.],
#         [ 0.,  0.,  0., 34., 50., 42., 37., 14.,  0.,  0.],
#         [ 0.,  0.,  0., 25.,  7., 14.,  0., 29.,  0.,  0.],
#         [ 0.,  0., 49.,  1.,  0.,  0.,  0., 20.,  1.,  0.],
#         [ 0.,  0., 13.,  0.,  0.,  0.,  0.,  0., 36.,  0.],
#         [ 0.,  0.,  0.,  0.,  0.,  0.,  0.,  0., 23.,  0.],
#         [ 2.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,  3., 32.],
#         [28., 32.,  0.,  0.,  0.,  0.,  0.,  0.,  0., 24.],
#         [32., 19.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  8.],
#         [ 1., 12.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]]),
#  array([ 40.849998 ,  52.8799976,  64.9099972,  76.9399968,  88.9699964,
#         100.999996 , 113.0299956, 125.0599952, 137.0899948, 149.1199944,
#         161.149994 ]),
#  array([  0.,  63., 126., 189., 252., 315., 378., 441., 504., 567., 630.]),
#  <matplotlib.collections.QuadMesh at 0x12b9c3d4860>)

# %%
import datetime as dt

# %%
date=df["Date"].tolist()
date
# Out:
# ['2021-07-23',
#  '2021-07-26',
#  '2021-07-27',
#  '2021-07-28',
#  '2021-07-29',
#  '2021-07-30',
#  '2021-08-02',
#  '2021-08-03',
#  '2021-08-04',
#  '2021-08-05',
#  '2021-08-06',
#  '2021-08-09',
#  '2021-08-10',
#  '2021-08-11',
#  '2021-08-12',
#  '2021-08-13',
#  '2021-08-16',
#  '2021-08-17',
#  '2021-08-18',
#  '2021-08-20',
#  '2021-08-23',
#  '2021-08-24',
#  '2021-08-25',
#  '2021-08-26',
#  '2021-08-27',
#  '2021-08-30',
#  '2021-08-31',
#  '2021-09-01',
#  '2021-09-02',
#  '2021-09-03',
#  '2021-09-06',
#  '2021-09-07',
#  '2021-09-08',
#  '2021-09-09',
#  '2021-09-13',
#  '2021-09-14',
#  '2021-09-15',
#  '2021-09-16',
#  '2021-09-17',
#  '2021-09-20',
#  '2021-09-21',
#  '2021-09-22',
#  '2021-09-23',
#  '2021-09-24',
#  '2021-09-27',
#  '2021-09-28',
#  '2021-09-29',
#  '2021-09-30',
#  '2021-10-01',
#  '2021-10-04',
#  '2021-10-05',
#  '2021-10-06',
#  '2021-10-07',
#  '2021-10-08',
#  '2021-10-11',
#  '2021-10-12',
#  '2021-10-13',
#  '2021-10-14',
# ...

# %%
year=[]
month=[]
day=[]

# %%
for i in date:
    t=i.split("-")
    year.append(int(t[0]))
    month.append(int(t[1]))
    day.append(int(t[2]))

# %%
year
# Out:
# [2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
# ...

# %%
df["year"]=year
df["month"]=month
df["day"]=day

# %%
df
# Out:
#            Open        High         Low       Close   Adj Close     Volume  \
# 0    116.000000  138.899994  115.000000  126.000000  126.000000  694895290
# 1    126.349998  143.750000  125.300003  140.649994  140.649994  249723854
# 2    141.699997  147.800003  127.750000  132.899994  132.899994  240341900
# 3    131.000000  135.000000  123.550003  131.199997  131.199997  159793731
# 4    134.949997  144.000000  132.199997  141.550003  141.550003  117973089
# ..          ...         ...         ...         ...         ...        ...
# 626  141.000000  143.500000  138.550003  140.550003  140.550003   70252449
# 627  141.800003  145.000000  141.449997  143.800003  143.800003   78666454
# 628  145.000000  145.399994  138.250000  140.250000  140.250000   54189688
# 629  140.399994  141.800003  138.050003  139.949997  139.949997   46782951
# 630  141.000000  142.899994  139.649994  140.399994  140.399994   75083259
#
#      year  month  day
# 0    2021      7   23
# ...

# %%
df=df.drop(["Date"],axis=1)

# %%
df
# Out:
#            Open        High         Low       Close   Adj Close     Volume  \
# 0    116.000000  138.899994  115.000000  126.000000  126.000000  694895290
# 1    126.349998  143.750000  125.300003  140.649994  140.649994  249723854
# 2    141.699997  147.800003  127.750000  132.899994  132.899994  240341900
# 3    131.000000  135.000000  123.550003  131.199997  131.199997  159793731
# 4    134.949997  144.000000  132.199997  141.550003  141.550003  117973089
# ..          ...         ...         ...         ...         ...        ...
# 626  141.000000  143.500000  138.550003  140.550003  140.550003   70252449
# 627  141.800003  145.000000  141.449997  143.800003  143.800003   78666454
# 628  145.000000  145.399994  138.250000  140.250000  140.250000   54189688
# 629  140.399994  141.800003  138.050003  139.949997  139.949997   46782951
# 630  141.000000  142.899994  139.649994  140.399994  140.399994   75083259
#
#      year  month  day
# 0    2021      7   23
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
test=df.drop(["High","Low","Open","Adj Close"],axis=1)

# %%
y=test["Close"].to_numpy()
x=test.drop(["Close"],axis=1)
x=x.to_numpy()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
# array([[49655881,     2023,        2,       15],
#        [48171753,     2023,       12,        6],
#        [25459694,     2023,        7,        5],
#        ...,
#        [30421931,     2021,        9,        7],
#        [57612020,     2024,        1,       30],
#        [62022927,     2023,        4,       19]], dtype=int64)

# %%
import sklearn as sk

# %%
model=sk.ensemble.RandomForestRegressor(n_estimators=10)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=10)

# %%
model.score(x_test,y_test)
# Out:
# 0.9445810532566189

# %%
x_train[-1]
# Out:
# array([62022927,     2023,        4,       19], dtype=int64)

# %%
model.predict(([820229270,2025,1,5],))
# Out:
# array([131.9049988])
