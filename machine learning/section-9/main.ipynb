# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("heart.csv")
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
x=df.drop("target",axis=1)
x
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal
# 0         2   2     3
# 1         0   0     3
# ...

# %%
y=df["target"]
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt

# %%
car_data=pd.read_csv("car-sales-extended.csv")
car_data
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
heart_data=pd.read_csv("heart.csv")
x=heart_data.drop("target",axis=1)
y=heart_data["target"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (820, 13)

# %%
car_data
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
x=car_data.drop("Price",axis=1)

# %%
y=car_data["Price"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#        Make Colour  Odometer (KM)  Doors
# 252   Honda   Blue         228037      4
# 606  Toyota  Black          71463      4
# 319  Nissan  White         102039      3
# 783  Toyota  Black         140913      4
# 368  Toyota    Red         180473      4
# ..      ...    ...            ...    ...
# 391  Toyota  White         177571      4
# 814     BMW   Blue          50363      5
# 77   Toyota  White         126669      4
# 698  Nissan  White          66199      4
# 336  Toyota  Green         165225      4
#
# [800 rows x 4 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor()

# %%
model.fit(x_train,y_train)
model.test(x_test,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19756\3116005686.py in ?()
# ----> 1 model.fit(x_train,y_train)
#       2 model.test(x_test,y_train)
#
# ~\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# ~\AppData\Roaming\Python\Python312\site-packages\sklearn\ensemble\_forest.py in ?(self, X, y, sample_weight)
#     359         # Validate or convert input data
#     360         if issparse(y):
#     361             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     362
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.compose import ColumnTransformer

# %%
car_data["Make"].value_counts()
# Out:
# Make
# Toyota    398
# Honda     304
# Nissan    198
# BMW       100
# Name: count, dtype: int64

# %%
categorical_feature=["Make","Colour","Doors"]

# %%
onehot=OneHotEncoder()
transformer=ColumnTransformer([("one_hot",onehot,categorical_feature)],remainder="passthrough")

# %%
transformer
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('one_hot', OneHotEncoder(),
#                                  ['Make', 'Colour', 'Doors'])])

# %%
transformed_x=transformer.fit_transform(x)
transformed_x
# Out:
# array([[0.00000e+00, 1.00000e+00, 0.00000e+00, ..., 1.00000e+00,
#         0.00000e+00, 3.54310e+04],
#        [1.00000e+00, 0.00000e+00, 0.00000e+00, ..., 0.00000e+00,
#         1.00000e+00, 1.92714e+05],
#        [0.00000e+00, 1.00000e+00, 0.00000e+00, ..., 1.00000e+00,
#         0.00000e+00, 8.47140e+04],
#        ...,
#        [0.00000e+00, 0.00000e+00, 1.00000e+00, ..., 1.00000e+00,
#         0.00000e+00, 6.66040e+04],
#        [0.00000e+00, 1.00000e+00, 0.00000e+00, ..., 1.00000e+00,
#         0.00000e+00, 2.15883e+05],
#        [0.00000e+00, 0.00000e+00, 0.00000e+00, ..., 1.00000e+00,
#         0.00000e+00, 2.48360e+05]])

# %%
x_train,x_test,y_train,y_test=train_test_split(transformed_x,y,test_size=0.2)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
model.score(x_test,y_test)
# Out:
# 0.015887302399751557

# %%
x_train
# Out:
# array([[0.00000e+00, 1.00000e+00, 0.00000e+00, ..., 1.00000e+00,
#         0.00000e+00, 1.78863e+05],
#        [0.00000e+00, 0.00000e+00, 1.00000e+00, ..., 1.00000e+00,
#         0.00000e+00, 2.48736e+05],
#        [0.00000e+00, 0.00000e+00, 1.00000e+00, ..., 1.00000e+00,
#         0.00000e+00, 1.66895e+05],
#        ...,
#        [0.00000e+00, 0.00000e+00, 1.00000e+00, ..., 1.00000e+00,
#         0.00000e+00, 1.97844e+05],
#        [0.00000e+00, 0.00000e+00, 1.00000e+00, ..., 0.00000e+00,
#         0.00000e+00, 1.07096e+05],
#        [0.00000e+00, 0.00000e+00, 0.00000e+00, ..., 1.00000e+00,
#         0.00000e+00, 7.13060e+04]])

# %%
missing=pd.read_csv("car-sales-extended-missing-data.csv")
missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
missing.isna().sum()
# Out:
# Make             49
# Colour           50
# Odometer (KM)    50
# Doors            50
# Price            50
# dtype: int64

# %%
x=missing.drop("Price",axis=1)
y=missing["Price"]
onehot=OneHotEncoder()
transformer=ColumnTransformer([("one_hot",onehot,categorical_feature)],remainder="passthrough")

# %%
transformed_x=transformer.fit_transform(x)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19756\4261664941.py in ?()
# ----> 1 model.fit(x_train,y_train)
#
# ~\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# ~\AppData\Roaming\Python\Python312\site-packages\sklearn\ensemble\_forest.py in ?(self, X, y, sample_weight)
#     359         # Validate or convert input data
#     360         if issparse(y):
#     361             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     362
# --> 363         X, y = self._validate_data(
#     364             X,
# ...

# %%
missing["Make"].fillna("missing",inplace=True)

# %%
missing["Colour"].fillna("missing",inplace=True)

# %%
missing["Odometer (KM)"].fillna(missing["Odometer (KM)"].mean(),inplace=True)
missing["Doors"].fillna(4,inplace=True)
# Out:
# C:\Users\praty\AppData\Local\Temp\ipykernel_19756\1520317186.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   missing["Odometer (KM)"].fillna(missing["Odometer (KM)"].mean(),inplace=True)
# C:\Users\praty\AppData\Local\Temp\ipykernel_19756\1520317186.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
model2=RandomForestRegressor()
x = missing.drop("Price", axis=1)
y = missing["Price"]

# %%
onehot=OneHotEncoder()

# %%
transformed_data=ColumnTransformer([("one_hot",onehot,["Make","Odometer (KM)","Colour"])],remainder="passthrough")

# %%
transformed_data
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('one_hot', OneHotEncoder(),
#                                  ['Make', 'Odometer (KM)', 'Colour'])])

# %%
x=missing.drop("Price",axis=1)

# %%
y=missing["Price"]

# %%
datasets=transformed_data.fit_transform(x)

# %%
datasets
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 4000 stored elements and shape (1000, 961)>

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_test
# Out:
#        Make Colour  Odometer (KM)  Doors
# 920  Nissan  White   19134.000000    4.0
# 329  Nissan   Blue  197823.000000    3.0
# 611  Toyota  Black  136271.000000    4.0
# 261  Toyota  White   61623.000000    4.0
# 316  Toyota  White  131253.237895    4.0
# ..      ...    ...            ...    ...
# 548  Toyota   Blue   89641.000000    4.0
# 828  Toyota    Red  220026.000000    4.0
# 809  Toyota  White  201039.000000    4.0
# 726     BMW  White  227845.000000    5.0
# 605   Honda  White   42137.000000    4.0
#
# [200 rows x 4 columns]
