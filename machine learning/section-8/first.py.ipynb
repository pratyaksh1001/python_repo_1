# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
fig,ax=plt.subplots()

# %%
ax.plot(np.random.randint(0,100,10))

# %%
ax
# Out:
# <Axes: >

# %%
fig

# %%
fig.savefig("first.jpeg")

# %%
fig2,ax2=plt.subplots()

# %%
x=np.linspace(0,10,100)

# %%
ax2.scatter(x,np.sin(x))

# %%
fig2

# %%
fig,((ax0,ax1),(ax2,ax3))=plt.subplots(nrows=2,ncols=2,figsize=(10,10))

# %%
ax0.plot(x,np.tan(x),label="tan")

# %%
fig

# %%
ax1.scatter(np.random.randint(0,100,100),x)

# %%
fig

# %%
ax2.bar(np.random.randint(0,100,100),x)
# Out:
# <BarContainer object of 100 artists>

# %%
fig

# %%
ax3.hist(np.tan(x))
# Out:
# (array([ 1.,  0.,  1.,  1.,  0.,  3., 59., 31.,  1.,  3.]),
#  array([-40.30416061, -34.47848701, -28.65281342, -22.82713983,
#         -17.00146624, -11.17579265,  -5.35011905,   0.47555454,
#           6.30122813,  12.12690172,  17.95257531]),
#  <BarContainer object of 10 artists>)

# %%
df=pd.read_csv("../section-6/car-sales.csv")

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
l=df.groupby("Colour").count()
l["Make"]
# Out:
# Colour
# Black    1
# Blue     3
# Green    1
# Red      1
# White    4
# Name: Make, dtype: int64

# %%
fig3,ax3=plt.subplots()
ax3.plot(l.index,l["Make"])

# %%
fig, ax=plt.subplots()

# %%
df.Price=df["Price"].str.replace("$","")
df.Price=df.Price.str.replace(",","")
df.Price=df.Price.str.replace(".","")
df.Price=df.Price.astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.Price=df["Price"].str.replace("$","")
#       2 df.Price=df.Price.str.replace(",","")
#       3 df.Price=df.Price.str.replace(".","")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %%
df["Price"]=df["Price"]/10

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   40000.0
# 1   Honda    Red          87899      4   50000.0
# 2  Toyota   Blue          32549      3   70000.0
# 3     BMW  Black          11179      5  220000.0
# 4  Nissan  White         213095      4   35000.0
# 5  Toyota  Green          99213      4   45000.0
# 6   Honda   Blue          45698      4   75000.0
# 7   Honda   Blue          54738      4   70000.0
# 8  Toyota  White          60000      4   62500.0
# 9  Nissan  White          31600      4   97000.0

# %%
ax.scatter(df["Odometer (KM)"].astype(int),df["Price"])
fig

# %%
import mysql.connector as con
connection=con.connect(user="root",password="7898",host="localhost")

# %%
cursor=connection.cursor()

# %%
l=cursor.execute("create database python1")

# %%
cursor.execute("show tables")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 cursor.execute("show tables")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\cursor.py:748, in MySQLCursor.execute(self, operation, params, multi)
#     745     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     747 try:
# --> 748     self._handle_result(self._connection.cmd_query(stmt))
#     749 except InterfaceError as err:
#     750     if self._connection.have_next_result:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\opentelemetry\context_propagation.py:102, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#     100 """Context propagation decorator."""
#     101 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# --> 102     return method(cnx, *args, **kwargs)
# ...

# %%
cursor.execute("use python1")

# %%
cursor.execute("show databases")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 print(cursor.execute("show databases"))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\cursor.py:713, in MySQLCursor.execute(self, operation, params, multi)
#     710 except (ProgrammingError, ReferenceError) as err:
#     711     raise ProgrammingError("Cursor is not connected") from err
# --> 713 self._connection.handle_unread_result()
#     715 self._reset_result()
#     716 stmt: StrOrBytes = ""
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:1548, in MySQLConnection.handle_unread_result(self)
#    1546     self.consume_results()
#    1547 elif self.unread_result:
# -> 1548     raise InternalError("Unread result found")
#
# InternalError: Unread result found

# %%
cursor.execute("show tables")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 cursor.execute("show tables")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\cursor.py:713, in MySQLCursor.execute(self, operation, params, multi)
#     710 except (ProgrammingError, ReferenceError) as err:
#     711     raise ProgrammingError("Cursor is not connected") from err
# --> 713 self._connection.handle_unread_result()
#     715 self._reset_result()
#     716 stmt: StrOrBytes = ""
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:1548, in MySQLConnection.handle_unread_result(self)
#    1546     self.consume_results()
#    1547 elif self.unread_result:
# -> 1548     raise InternalError("Unread result found")
#
# InternalError: Unread result found

# %%
cursor.execute("select * from student")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 cursor.execute("select * from student")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\cursor.py:713, in MySQLCursor.execute(self, operation, params, multi)
#     710 except (ProgrammingError, ReferenceError) as err:
#     711     raise ProgrammingError("Cursor is not connected") from err
# --> 713 self._connection.handle_unread_result()
#     715 self._reset_result()
#     716 stmt: StrOrBytes = ""
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:1548, in MySQLConnection.handle_unread_result(self)
#    1546     self.consume_results()
#    1547 elif self.unread_result:
# -> 1548     raise InternalError("Unread result found")
#
# InternalError: Unread result found
