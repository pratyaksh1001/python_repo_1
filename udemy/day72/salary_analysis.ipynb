# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('salaries_by_college_major.csv')

# %%
df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
df.sort_index(axis=1)
# Out:
#        Group  Mid-Career 10th Percentile Salary  \
# 0   Business                            42200.0
# 1       STEM                            64300.0
# 2   Business                            36300.0
# 3       HASS                            33800.0
# 4   Business                            50600.0
# 5       HASS                            28800.0
# 6       STEM                            36900.0
# 7   Business                            38800.0
# 8       STEM                            71900.0
# 9       STEM                            45300.0
# 10      STEM                            63400.0
# 11      HASS                            37500.0
# 12      STEM                            66100.0
# 13      STEM                            56000.0
# 14  Business                            56300.0
# 15      HASS                            32200.0
# 16      HASS                            36700.0
# 17  Business                            50600.0
# ...

# %%
df.sort_values(by='Starting Median Salary')
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 49                               Spanish                 34000.0
# 47                              Religion                 34100.0
# 18                             Education                 34900.0
# 15                      Criminal Justice                 35000.0
# 34                            Journalism                 35600.0
# 26                        Graphic Design                 35700.0
# 5                            Art History                 35800.0
# 16                                 Drama                 35900.0
# 46                            Psychology                 35900.0
# 39                                 Music                 35900.0
# 32                       Interior Design                 36100.0
# 48                             Sociology                 36500.0
# 3                           Anthropology                 36800.0
# ...

# %%
df.sort_values(by='Starting Median Salary',ascending=False)
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 43                   Physician Assistant                 74300.0
# 8                   Chemical Engineering                 63200.0
# 12                  Computer Engineering                 61400.0
# 19                Electrical Engineering                 60900.0
# 38                Mechanical Engineering                 57900.0
# 1                  Aerospace Engineering                 57700.0
# 30                Industrial Engineering                 57700.0
# 13                      Computer Science                 55900.0
# 40                               Nursing                 54200.0
# 10                     Civil Engineering                 53900.0
# 14                          Construction                 53700.0
# 44                               Physics                 50300.0
# 17                             Economics                 50100.0
# ...

# %%
df.sort_values(by='Starting Median Salary',ascending=False)
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 43                   Physician Assistant                 74300.0
# 8                   Chemical Engineering                 63200.0
# 12                  Computer Engineering                 61400.0
# 19                Electrical Engineering                 60900.0
# 38                Mechanical Engineering                 57900.0
# 1                  Aerospace Engineering                 57700.0
# 30                Industrial Engineering                 57700.0
# 13                      Computer Science                 55900.0
# 40                               Nursing                 54200.0
# 10                     Civil Engineering                 53900.0
# 14                          Construction                 53700.0
# 44                               Physics                 50300.0
# 17                             Economics                 50100.0
# ...

# %%
df.count(axis=0)
# Out:
# Undergraduate Major                  51
# Starting Median Salary               50
# Mid-Career Median Salary             50
# Mid-Career 10th Percentile Salary    50
# Mid-Career 90th Percentile Salary    50
# Group                                50
# dtype: int64

# %%
df.count(axis=0).median
# Out:
# <bound method Series.median of Undergraduate Major                  51
# Starting Median Salary               50
# Mid-Career Median Salary             50
# Mid-Career 10th Percentile Salary    50
# Mid-Career 90th Percentile Salary    50
# Group                                50
# dtype: int64>

# %%
df.sort_values(by='Starting Median Salary',ascending=False)
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 43                   Physician Assistant                 74300.0
# 8                   Chemical Engineering                 63200.0
# 12                  Computer Engineering                 61400.0
# 19                Electrical Engineering                 60900.0
# 38                Mechanical Engineering                 57900.0
# 1                  Aerospace Engineering                 57700.0
# 30                Industrial Engineering                 57700.0
# 13                      Computer Science                 55900.0
# 40                               Nursing                 54200.0
# 10                     Civil Engineering                 53900.0
# 14                          Construction                 53700.0
# 44                               Physics                 50300.0
# 17                             Economics                 50100.0
# ...

# %%
df.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x0000024504A62F00>

# %%
len(df.iterrows())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 len(df.iterrows())
#
# TypeError: object of type 'generator' has no len()

# %%
df.shape
# Out:
# (51, 6)

# %%
df.isna
# Out:
# <bound method DataFrame.isna of                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
df=df.dropna(axis=0,how='any')

# %%
df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
df['Starting Median Salary']
# Out:
# 0     46000.0
# 1     57700.0
# 2     42600.0
# 3     36800.0
# 4     41600.0
# 5     35800.0
# 6     38800.0
# 7     43000.0
# 8     63200.0
# 9     42600.0
# 10    53900.0
# 11    38100.0
# 12    61400.0
# 13    55900.0
# 14    53700.0
# 15    35000.0
# 16    35900.0
# 17    50100.0
# 18    34900.0
# 19    60900.0
# 20    38000.0
# 21    37900.0
# 22    47900.0
# 23    39100.0
# 24    41200.0
# 25    43500.0
# 26    35700.0
# 27    38800.0
# 28    39200.0
# 29    37800.0
# 30    57700.0
# 31    49100.0
# 32    36100.0
# 33    40900.0
# 34    35600.0
# 35    49200.0
# 36    40800.0
# 37    45400.0
# 38    57900.0
# 39    35900.0
# 40    54200.0
# 41    39900.0
# 42    39900.0
# 43    74300.0
# 44    50300.0
# 45    40800.0
# 46    35900.0
# 47    34100.0
# 48    36500.0
# 49    34000.0
# Name: Starting Median Salary, dtype: float64

# %%
m=df['Mid-Career Median Salary'].min()
m=int(m)
m
# Out:
# 52000

# %%
df[df['Mid-Career Median Salary']==m]
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 18           Education                 34900.0                   52000.0
# 47            Religion                 34100.0                   52000.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 18                            29300.0                           102000.0  HASS
# 47                            29700.0                            96400.0  HASS

# %%
newdf=df.copy()

# %%
diff_col=df['Mid-Career 90th Percentile Salary']-df['Mid-Career 10th Percentile Salary']
diff_col
# Out:
# 0     109800.0
# 1      96700.0
# 2     113700.0
# 3     104200.0
# 4      85400.0
# 5      96200.0
# 6      98100.0
# 7     108200.0
# 8     122100.0
# 9     102700.0
# 10     84600.0
# 11    105500.0
# 12     95900.0
# 13     98000.0
# 14    114700.0
# 15     74800.0
# 16    116300.0
# 17    159400.0
# 18     72700.0
# 19     98700.0
# 20     99600.0
# 21    102100.0
# 22    147800.0
# 23     70000.0
# 24     92000.0
# 25    111000.0
# 26     76000.0
# 27     66400.0
# 28    112000.0
# 29     88500.0
# 30    115900.0
# 31     84500.0
# 32     71300.0
# 33    118800.0
# 34    106600.0
# 35    100700.0
# 36    132900.0
# 37    137800.0
# 38     99300.0
# 39    107300.0
# 40     50700.0
# 41     65300.0
# 42    132500.0
# 43     57600.0
# 44    122000.0
# 45    126800.0
# 46     95400.0
# 47     66700.0
# 48     87300.0
# 49     65400.0
# dtype: float64

# %%
newdf.insert(1,'Difference',diff_col)

# %%
newdf.sort_values(by='Difference')
# Out:
#                      Undergraduate Major  Difference  Starting Median Salary  \
# 40                               Nursing     50700.0                 54200.0
# 43                   Physician Assistant     57600.0                 74300.0
# 41                             Nutrition     65300.0                 39900.0
# 49                               Spanish     65400.0                 34000.0
# 27            Health Care Administration     66400.0                 38800.0
# 47                              Religion     66700.0                 34100.0
# 23                              Forestry     70000.0                 39100.0
# 32                       Interior Design     71300.0                 36100.0
# 18                             Education     72700.0                 34900.0
# 15                      Criminal Justice     74800.0                 35000.0
# 26                        Graphic Design     76000.0                 35700.0
# ...

# %%
overall_median_salary=df['Mid-Career Median Salary'].median()
overall_median_salary=int(overall_median_salary)
overall_median_salary
# Out:
# 72000

# %%
newdf[newdf['Mid-Career Median Salary']>overall_median_salary].sort_values(by='Difference',ascending=False)
# Out:
#                      Undergraduate Major  Difference  Starting Median Salary  \
# 17                             Economics    159400.0                 50100.0
# 22                               Finance    147800.0                 47900.0
# 37                                  Math    137800.0                 45400.0
# 36                             Marketing    132900.0                 40800.0
# 42                            Philosophy    132500.0                 39900.0
# 45                     Political Science    126800.0                 40800.0
# 8                   Chemical Engineering    122100.0                 63200.0
# 44                               Physics    122000.0                 50300.0
# 33               International Relations    118800.0                 40900.0
# 30                Industrial Engineering    115900.0                 57700.0
# 14                          Construction    114700.0                 53700.0
# ...

# %%
newdf.groupby('Group').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...
